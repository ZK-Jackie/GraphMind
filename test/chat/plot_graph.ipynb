# %% [markdown]
# #### 测试绘制 LangGraph Agent 结构图

# %%
from graphmind.service.chat.chat_agent.agent import GraphAgent
from IPython.display import Image, display

agent = GraphAgent().agent_with_history
display(Image(agent.get_graph().draw_mermaid_png()))

# %%
from graphmind.service.chat.chat_agent.sub_graphs.cypher_graph import CypherGraph

sub_agent = CypherGraph().agent_with_history
display(Image(sub_agent.get_graph().draw_mermaid_png()))
